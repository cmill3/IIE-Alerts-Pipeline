# %%
import pandas as pd
import boto3

# %%
## pull all files from a specific filepath in s3 and read the contents and turn into csv
def pull_files_from_s3(filepath):
    s3 = boto3.client('s3')
    ## list all the files in a filepath using s3 client

    file_keys = []
    dfs = []
    # Use paginator to handle listing of large number of objects
    paginator = s3.get_paginator('list_objects_v2')
    page_iterator = paginator.paginate(Bucket="inv-alerts", Prefix=filepath)

    for page in page_iterator:
        if 'Contents' in page:
            for obj in page['Contents']:
                file_keys.append(obj['Key'])
    for file in file_keys:
        response = s3.get_object(Bucket="inv-alerts", Key=file)
        body = response['Body']
        df = pd.read_csv(body)
        dfs.append(df)
    return dfs

# %%
dfs = []
for year in [2022,2023,2024]:
    year_dfs = pull_files_from_s3(f'trend_alerts/{year}/')
    dfs.extend(year_dfs)

## concatenate all the dataframes into one
df = pd.concat(dfs)

# %%
### Study and build the filter level for the volume Z-score, data exists
df.groupby('hour')['volume_cycle_z_scores'].describe()
# Out:
#          count      mean       std       min       25%       50%       75%  \
# hour
# 10    124272.0  0.157687  0.693115 -3.467769 -0.298052  0.077995  0.536738
# 11    124275.0  0.324996  0.724263 -3.467769 -0.154559  0.250081  0.736060
# 12    124279.0  0.342333  0.719421 -3.467769 -0.138011  0.269234  0.762468
# 13    124277.0  0.003157  0.747809 -3.467769 -0.502701 -0.073757  0.432943
# 14    123848.0 -0.580549  0.602673 -3.474143 -0.988177 -0.624305 -0.243852
# 15    123855.0 -0.596983  0.552090 -3.467769 -0.969028 -0.638257 -0.287490
#
#            max
# hour
# 10    3.356276
# 11    3.250109
# 12    3.322981
# 13    3.172622
# 14    3.020244
# 15    3.144146

# %%
df.groupby('hour')['return_vol_8H'].describe()
# Out:
#          count      mean       std       min       25%       50%       75%  \
# hour
# 10    139355.0  0.006505  0.004561  0.000324  0.003479  0.005300  0.008131
# 11    139359.0  0.006064  0.004169  0.000370  0.003282  0.004964  0.007588
# 12    139363.0  0.005902  0.004083  0.000364  0.003188  0.004824  0.007373
# 13    139361.0  0.005830  0.004054  0.000339  0.003143  0.004753  0.007288
# 14    139314.0  0.005821  0.004072  0.000353  0.003130  0.004737  0.007263
# 15    139209.0  0.005810  0.004069  0.000274  0.003125  0.004734  0.007252
#
#            max
# hour
# 10    0.087921
# 11    0.076815
# 12    0.075575
# 13    0.075210
# 14    0.080192
# 15    0.081090

# %%
df.groupby('hour')['range_volatility'].describe()
# Out:
#          count      mean       std       min       25%       50%       75%  \
# hour
# 10    124272.0  0.013339  0.010206  0.000105  0.006720  0.010529  0.016699
# 11    124275.0  0.007895  0.005524  0.000105  0.004287  0.006403  0.009778
# 12    124279.0  0.006256  0.004339  0.000000  0.003430  0.005107  0.007770
# 13    124277.0  0.005587  0.004028  0.000000  0.003033  0.004546  0.006927
# 14    123848.0  0.005417  0.004072  0.000000  0.002919  0.004351  0.006621
# 15    123855.0  0.005511  0.004365  0.000000  0.002912  0.004364  0.006691
#
#            max
# hour
# 10    0.230556
# 11    0.127804
# 12    0.124392
# 13    0.097721
# 14    0.138334
# 15    0.112673

# %%
df['hour_vol_8hour_diff'] = (df['price_change_absolute_H'] - df['return_vol_8H'])/df['return_vol_8H']
df.groupby('hour')['hour_vol_8hour_diff'].describe()
# Out:
#          count      mean       std  min       25%       50%       75%  \
# hour
# 10    139355.0  0.322983  1.077284 -1.0 -0.496324  0.061550  0.866627
# 11    139359.0 -0.069433  0.755257 -1.0 -0.644832 -0.249344  0.312449
# 12    139363.0 -0.250957  0.622607 -1.0 -0.717110 -0.400395  0.049978
# 13    139361.0 -0.336263  0.565428 -1.0 -0.754029 -0.474325 -0.074896
# 14    139314.0 -0.348560  0.565045 -1.0 -0.760223 -0.487160 -0.097335
# 15    139209.0 -0.357292  0.569771 -1.0 -0.767083 -0.501227 -0.111373
#
#            max
# hour
# 10    6.518175
# 11    5.228401
# 12    5.741276
# 13    5.434529
# 14    5.241799
# 15    5.785447

# %%
df['cd_vol'] = (df['return_vol_8H']/df['return_vol_5D']).round(3)
df.groupby('hour')['cd_vol'].describe()
# Out:
#          count      mean       std    min    25%    50%    75%    max
# hour
# 10    139348.0  0.406379  0.198436  0.022  0.276  0.370  0.492  5.246
# 11    139351.0  0.376397  0.190131  0.023  0.253  0.340  0.454  5.561
# 12    139355.0  0.363994  0.187456  0.029  0.243  0.328  0.439  5.580
# 13    139353.0  0.357962  0.187735  0.026  0.237  0.321  0.431  4.612
# 14    139306.0  0.355887  0.187665  0.028  0.234  0.318  0.429  4.967
# 15    139201.0  0.353223  0.188191  0.013  0.232  0.315  0.427  5.021
