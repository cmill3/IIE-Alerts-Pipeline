# %%
import boto3
import pandas as pd
import warnings
import ast

s3 = boto3.client('s3')

# %% [markdown]
# ### Analysis of BFC TFS Process

# %%
base_path = '/Users/charlesmiller/Documents/temporal_simulation_results'
bfc_df = pd.read_csv(f'{base_path}/CDBFC/2024_4_23.csv')

# %%
df = bfc_df
df = df.sort_values('median_gross_accuracy', ascending=False).reset_index(drop=True)
df['gross_acc_median_rank'] = df.index + 1
df = df.sort_values('median_tp', ascending=False).reset_index(drop=True)
df['median_tp_rank'] = df.index + 1
df = df.sort_values('tp_avg', ascending=False).reset_index(drop=True)
df['tp_avg_rank'] = df.index + 1
df = df.sort_values('gross_accuracy', ascending=False).reset_index(drop=True)
df['gross_acc_rank'] = df.index + 1
df['weighted_rank'] = (df['gross_acc_median_rank'] + df['median_tp_rank'] + df['tp_avg_rank'] + df['gross_acc_rank'])/4
df.sort_values('weighted_rank', ascending=True,inplace=True)

# %%
df.head(10)
# Out:
#                       model_name  \
# 0   CDBFC_temporal_simulation_41
# 1   CDBFC_temporal_simulation_10
# 9   CDBFC_temporal_simulation_64
# 7   CDBFC_temporal_simulation_76
# 4   CDBFC_temporal_simulation_99
# 6   CDBFC_temporal_simulation_90
# 2   CDBFC_temporal_simulation_53
# 11  CDBFC_temporal_simulation_34
# 10  CDBFC_temporal_simulation_78
# 8   CDBFC_temporal_simulation_32
#
#                                              features     tp_avg  \
# 0   ['price_change_H', 'day_of_month', 'cmf_15MA_d...  80.251497
# 1   ['High-Close', 'cmf_15MA', 'SPY_5d_diff', 'day...  79.904192
# 9   ['roc3', 'roc5', 'macd_15MA_diff', 'DMplus', '...  79.215569
# 7   ['price_range', 'SPY_5d', 'macd_15MA', 'day_of...  79.299401
# 4   ['month', 'return_vol_5D', 'DX', 'cmf_15MA_dif...  78.796407
# 6   ['price_change_H', 'DIminus', 'price_3D20D_dif...  79.742515
# 2   ['volume_sum15_5DMA_diff', 'return_vol_10D', '...  76.502994
# 11  ['cmf_15MA_diff', 'DIminus', 'High-Close', 'pr...  77.311377
# 10  ['price_change_H', 'High-Close', 'return_vol_1...  77.712575
# 8   ['bb_spread', 'H-PrevClose', 'rsi_15MA', 'macd...  78.934132
#
#     gross_accuracy  num_features  median_tp  median_gross_accuracy  \
# 0        17.574850            41       69.0                   11.0
# 1        16.790419            47       65.0                   13.0
# 9        15.514970            46       65.0                   13.0
# 7        15.922156            44       64.0                   14.0
# 4        16.149701            36       63.0                   14.0
# 6        16.029940            48       65.0                   11.0
# 2        16.544910            36       65.0                   13.0
# 11       14.904192            36       65.0                   15.0
# 10       15.323353            46       67.0                   12.0
# 8        15.550898            47       63.0                   14.0
#
#     gross_acc_median_rank  median_tp_rank  tp_avg_rank  gross_acc_rank  \
# 0                      23               2            1               1
# 1                      11              13            2               2
# 9                      10              16            5              10
# 7                       8              22            4               8
# 4                       5              26            7               5
# 6                      25              10            3               7
# 2                      12               9           22               3
# 11                      4              14           17              12
# 10                     18               5           14              11
# 8                       7              28            6               9
#
#     weighted_rank
# 0            6.75
# 1            7.00
# 9           10.25
# 7           10.50
# 4           10.75
# 6           11.25
# 2           11.50
# 11          11.75
# 10          12.00
# 8           12.50

# %%
## Statistics of note
print(f"Best Strategies avg features {bfc_df.head(10)['num_features'].mean()}")
print(f"Best Strategies avg gross accuracy {bfc_df.head(10)['gross_accuracy'].mean()}")
print(f"Best Strategies avg median gross accuracy {bfc_df.head(10)['median_gross_accuracy'].mean()}")
print(f"Best Strategies avg median tp {bfc_df.head(10)['median_tp'].mean()}")
print(f"Best Strategies avg tp avg {bfc_df.head(10)['tp_avg'].mean()}")
# Out:
# Best Strategies avg features 37.1
# Best Strategies avg gross accuracy 7.727544910179641
# Best Strategies avg median gross accuracy 5.4
# Best Strategies avg median tp 55.8
# Best Strategies avg tp avg 69.86946107784432

# %%
df['features'] = df['features'].apply(lambda x: ast.literal_eval(x))
feature_df = df.explode('features')

# %%
feature_rank_avg = feature_df.groupby('features')['weighted_rank'].mean()
top_25_features_bfc = pd.DataFrame(feature_rank_avg).sort_values('weighted_rank', ascending=True).index.tolist()
print(top_25_features_bfc)
# Out:
# ['price_change_H', 'cd_vol', 'price_range', 'bb_trend', 'price_range_5DMA_diff', 'roc', 'bb_category', 'bb_spread', 'volume_15MA_diff', 'price_change_D', 'month', 'return_vol_10D', 'PrevClose-L', 'roc3', 'H-L', 'TR', 'volume_sum15', 'return_vol_5D_diff', 'price_3Ddiff', 'roc_15MA', 'macd_15MA_diff', 'rsi_15MA', 'SPY_5d_diff', 'return_vol_8H_diff', 'High-Close', 'DMminus', 'hour', 'return_vol_10D_diff', 'H-PrevClose', 'DMplus', 'DX', 'SPY_range_vol', 'Low-Close', 'price_5Ddiff', 'volume_sum15_10DMA_diff', 'rsi', 'cmf_15MA_diff', 'return_vol_5D', 'price_10Ddiff', 'day_of_week', 'High-Low', 'roc_15MA_diff', 'cmf', 'volume_sum15_5DMA_diff', 'SPY_20d', 'macd_15MA', 'day_of_month', 'adx', 'price_range_8MA_diff', 'cd_vol3', 'DIplus', 'return_vol_8H', 'price_20Ddiff', 'cmf_15MA', 'price_3D20D_diff', 'SPY_5d', 'SPY_20d_diff', 'rsi_15MA_diff', 'macd', 'roc5', 'DIminus']

# %%
x = ['price_change_H', 'cd_vol', 'price_range', 'bb_trend', 'price_range_5DMA_diff', 'roc', 'bb_category', 'bb_spread', 'volume_15MA_diff', 'price_change_D', 'month', 'return_vol_10D', 'PrevClose-L', 'roc3', 'H-L', 'TR', 'volume_sum15', 'return_vol_5D_diff', 'price_3Ddiff', 'roc_15MA', 'macd_15MA_diff', 'rsi_15MA', 'SPY_5d_diff', 'return_vol_8H_diff', 'High-Close', 'DMminus', 'hour', 'return_vol_10D_diff', 'H-PrevClose', 'DMplus', 'DX', 'SPY_range_vol', 'Low-Close', 'price_5Ddiff', 'volume_sum15_10DMA_diff', 'rsi', 'cmf_15MA_diff', 'return_vol_5D', 'price_10Ddiff', 'day_of_week', 'High-Low', 'roc_15MA_diff', 'cmf', 'volume_sum15_5DMA_diff', 'SPY_20d', 'macd_15MA', 'day_of_month', 'adx', 'price_range_8MA_diff', 'cd_vol3', 'DIplus', 'return_vol_8H', 'price_20Ddiff', 'cmf_15MA', 'price_3D20D_diff', 'SPY_5d', 'SPY_20d_diff', 'rsi_15MA_diff', 'macd', 'roc5', 'DIminus']
print(len(x))
# Out:
# 61

# %% [markdown]
# ### Analysis of BFP TFS Process

# %%
base_path = '/Users/charlesmiller/Documents/temporal_simulation_results'
bfp_df = pd.read_csv(f'{base_path}/CDBFP/2024_4_23.csv')

# %%
df = bfp_df
df = df.sort_values('median_gross_accuracy', ascending=False).reset_index(drop=True)
df['gross_acc_median_rank'] = df.index + 1
df = df.sort_values('median_tp', ascending=False).reset_index(drop=True)
df['median_tp_rank'] = df.index + 1
df = df.sort_values('tp_avg', ascending=False).reset_index(drop=True)
df['tp_avg_rank'] = df.index + 1
df = df.sort_values('gross_accuracy', ascending=False).reset_index(drop=True)
df['gross_acc_rank'] = df.index + 1
df['weighted_rank'] = (df['gross_acc_median_rank'] + df['median_tp_rank'] + df['tp_avg_rank'] + df['gross_acc_rank'])/4
df.sort_values('weighted_rank', ascending=True,inplace=True)

# %%
df.head(10)
# Out:
#                       model_name  \
# 0   CDBFP_temporal_simulation_67
# 13  CDBFP_temporal_simulation_83
# 8   CDBFP_temporal_simulation_91
# 2   CDBFP_temporal_simulation_54
# 4   CDBFP_temporal_simulation_77
# 17  CDBFP_temporal_simulation_82
# 1   CDBFP_temporal_simulation_60
# 3   CDBFP_temporal_simulation_65
# 5   CDBFP_temporal_simulation_34
# 19  CDBFP_temporal_simulation_17
#
#                                              features     tp_avg  \
# 0   ['volume_15MA_diff', 'day_of_month', 'price_ch...  77.964072
# 13  ['return_vol_10D_diff', 'return_vol_8H', 'pric...  77.832335
# 8   ['H-L', 'cd_vol', 'price_range_5DMA_diff', 'pr...  76.988024
# 2   ['cmf_15MA', 'TR', 'roc', 'bb_category', 'DIpl...  75.017964
# 4   ['return_vol_8H_diff', 'price_change_D', 'day_...  78.143713
# 17  ['volume_sum15_10DMA_diff', 'SPY_5d_diff', 'ma...  77.089820
# 1   ['price_change_H', 'price_3D20D_diff', 'return...  77.017964
# 3   ['roc_15MA', 'macd_15MA', 'adx', 'price_20Ddif...  77.664671
# 5   ['macd_15MA', 'return_vol_10D', 'bb_trend', 'p...  74.239521
# 19  ['return_vol_10D', 'DX', 'PrevClose-L', 'price...  75.736527
#
#     gross_accuracy  num_features  median_tp  median_gross_accuracy  \
# 0        19.994012            40       72.0                   11.0
# 13       18.191617            41       74.0                   11.0
# 8        18.670659            47       69.0                   10.0
# 2        19.886228            42       70.0                    9.0
# 4        19.425150            33       68.0                    8.0
# 17       17.832335            30       68.0                   10.0
# 1        19.976048            40       69.0                    8.0
# 3        19.742515            43       71.0                    7.0
# 5        19.317365            32       66.0                   11.0
# 19       17.437126            41       67.0                   11.0
#
#     gross_acc_median_rank  median_tp_rank  tp_avg_rank  gross_acc_rank  \
# 0                       7               2            2               1
# 13                      8               1            3              14
# 8                      14              11            9               9
# 2                      22               6           15               3
# 4                      26              14            1               5
# 17                      9              12            7              18
# 1                      29              10            8               2
# 3                      37               4            4               4
# 5                       5              22           22               6
# 19                      6              19           13              20
#
#     weighted_rank
# 0            3.00
# 13           6.50
# 8           10.75
# 2           11.50
# 4           11.50
# 17          11.50
# 1           12.25
# 3           12.25
# 5           13.75
# 19          14.50

# %%
## Statistics of note
print(f"Best Strategies avg features {df.head(10)['num_features'].mean()}")
print(f"Best Strategies avg gross accuracy {df.head(10)['gross_accuracy'].mean()}")
print(f"Best Strategies avg median gross accuracy {df.head(10)['median_gross_accuracy'].mean()}")
print(f"Best Strategies avg median tp {df.head(10)['median_tp'].mean()}")
print(f"Best Strategies avg tp avg {df.head(10)['tp_avg'].mean()}")
# Out:
# Best Strategies avg features 38.9
# Best Strategies avg gross accuracy 19.047305389221556
# Best Strategies avg median gross accuracy 9.6
# Best Strategies avg median tp 69.4
# Best Strategies avg tp avg 76.76946107784431

# %%
df['features'] = df['features'].apply(lambda x: ast.literal_eval(x))
feature_df = df.explode('features')

# %%
feature_rank_avg = feature_df.groupby('features')['weighted_rank'].mean()
top_25_features_bfp = pd.DataFrame(feature_rank_avg).sort_values('weighted_rank', ascending=True).index.tolist()
top_25_features_bfp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 feature_rank_avg = feature_df.groupby('features')['weighted_rank'].mean()
#       2 top_25_features_bfp = pd.DataFrame(feature_rank_avg).sort_values('weighted_rank', ascending=True).index.tolist()
#       3 top_25_features_bfp
#
# NameError: name 'feature_df' is not defined

# %% [markdown]
# ### Analysis of BFC_1D

# %%
base_path = '/Users/charlesmiller/Documents/temporal_simulation_results'
bfc1d_df = pd.read_csv(f'{base_path}/CDBFC_1D/2024_4_24.csv')

# %%
df = bfc1d_df
df = df.sort_values('median_gross_accuracy', ascending=False).reset_index(drop=True)
df['gross_acc_median_rank'] = df.index + 1
df = df.sort_values('median_tp', ascending=False).reset_index(drop=True)
df['median_tp_rank'] = df.index + 1
df = df.sort_values('tp_avg', ascending=False).reset_index(drop=True)
df['tp_avg_rank'] = df.index + 1
df = df.sort_values('gross_accuracy', ascending=False).reset_index(drop=True)
df['gross_acc_rank'] = df.index + 1
df['weighted_rank'] = (df['gross_acc_median_rank'] + df['median_tp_rank'] + df['tp_avg_rank'] + df['gross_acc_rank'])/4
df.sort_values('weighted_rank', ascending=True,inplace=True)

# %%
df.head(10)
# Out:
#                          model_name  \
# 0   CDBFC_1D_temporal_simulation_29
# 2    CDBFC_1D_temporal_simulation_5
# 5   CDBFC_1D_temporal_simulation_22
# 6    CDBFC_1D_temporal_simulation_0
# 10   CDBFC_1D_temporal_simulation_2
# 9   CDBFC_1D_temporal_simulation_38
# 17  CDBFC_1D_temporal_simulation_25
# 16  CDBFC_1D_temporal_simulation_34
# 3   CDBFC_1D_temporal_simulation_17
# 11  CDBFC_1D_temporal_simulation_24
#
#                                              features      tp_avg  \
# 0   ['price_range_8MA_diff', 'rsi_15MA', 'roc', 'r...  135.622754
# 2   ['price_5Ddiff', 'cmf_15MA_diff', 'price_3Ddif...  134.538922
# 5   ['price_20Ddiff', 'SPY_5d', 'return_vol_5D', '...  134.640719
# 6   ['rsi_15MA', 'price_3Ddiff', 'roc5', 'macd_15M...  133.233533
# 10  ['price_3Ddiff', 'H-L', 'bb_trend', 'macd', 'v...  131.628743
# 9   ['DMminus', 'macd', 'rsi_15MA_diff', 'Low-Clos...  133.676647
# 17  ['bb_category', 'SPY_5d', 'return_vol_5D_diff'...  133.940120
# 16  ['roc', 'High-Close', 'cmf_15MA', 'price_range...  131.059880
# 3   ['return_vol_10D', 'price_5Ddiff', 'price_10Dd...  130.329341
# 11  ['rsi', 'price_5Ddiff', 'DX', 'day_of_month', ...  130.227545
#
#     gross_accuracy  num_features  median_tp  median_gross_accuracy  \
# 0        23.467066            43      121.0                   30.0
# 2        20.131737            43      127.0                   24.0
# 5        18.880240            43      112.0                   26.0
# 6        17.796407            47      117.0                   24.0
# 10       16.694611            32      114.0                   25.0
# 9        16.934132            43      112.0                   24.0
# 17       14.646707            39      115.0                   24.0
# 16       15.083832            45      119.0                   25.0
# 3        19.443114            48      112.0                   26.0
# 11       16.670659            40      115.0                   26.0
#
#     gross_acc_median_rank  median_tp_rank  tp_avg_rank  gross_acc_rank  \
# 0                       1               3            2               1
# 2                      13               1            5               3
# 5                       3              17            4               6
# 6                      12               5            8               7
# 10                      7              11           15              11
# 9                       9              18            7              10
# 17                     11               9            6              18
# 16                      8               4           18              17
# 3                       4              19           21               4
# 11                      5              10           22              12
#
#     weighted_rank
# 0            1.75
# 2            5.50
# 5            7.50
# 6            8.00
# 10          11.00
# 9           11.00
# 17          11.00
# 16          11.75
# 3           12.00
# 11          12.25

# %%
## Statistics of note
print(f"Best Strategies avg features {df.head(10)['num_features'].mean()}")
print(f"Best Strategies avg gross accuracy {df.head(10)['gross_accuracy'].mean()}")
print(f"Best Strategies avg median gross accuracy {df.head(10)['median_gross_accuracy'].mean()}")
print(f"Best Strategies avg median tp {df.head(10)['median_tp'].mean()}")
print(f"Best Strategies avg tp avg {df.head(10)['tp_avg'].mean()}")
# Out:
# Best Strategies avg features 42.3
# Best Strategies avg gross accuracy 17.974850299401197
# Best Strategies avg median gross accuracy 25.4
# Best Strategies avg median tp 116.4
# Best Strategies avg tp avg 132.88982035928143

# %%
df['features'] = df['features'].apply(lambda x: ast.literal_eval(x))
feature_df = df.explode('features')

# %%
## top 20 only bc of interrupted test
feature_rank_avg = feature_df.groupby('features')['weighted_rank'].mean()
top_25_features_bfc1d = pd.DataFrame(feature_rank_avg).sort_values('weighted_rank', ascending=True)
top_25_features_bfc1d
# Out:
# ['price_change_H',
#  'PrevClose-L',
#  'return_vol_10D',
#  'price_5Ddiff',
#  'volume_sum15_5DMA_diff',
#  'return_vol_8H_diff',
#  'roc5',
#  'cd_vol3',
#  'H-PrevClose',
#  'TR',
#  'day_of_week',
#  'bb_category',
#  'macd_15MA_diff',
#  'price_change_D',
#  'rsi',
#  'price_range_5DMA_diff',
#  'High-Low',
#  'H-L',
#  'roc',
#  'return_vol_5D_diff']

# %% [markdown]
# ### Analysis of BFP_1D

# %%
base_path = '/Users/charlesmiller/Documents/temporal_simulation_results'
bfp1d_df = pd.read_csv(f'{base_path}/CDBFP_1D/2024_4_23.csv')

# %%
df = bfp1d_df
df = df.sort_values('median_gross_accuracy', ascending=False).reset_index(drop=True)
df['gross_acc_median_rank'] = df.index + 1
df = df.sort_values('median_tp', ascending=False).reset_index(drop=True)
df['median_tp_rank'] = df.index + 1
df = df.sort_values('tp_avg', ascending=False).reset_index(drop=True)
df['tp_avg_rank'] = df.index + 1
df = df.sort_values('gross_accuracy', ascending=False).reset_index(drop=True)
df['gross_acc_rank'] = df.index + 1
df['weighted_rank'] = (df['gross_acc_median_rank'] + df['median_tp_rank'] + df['tp_avg_rank'] + df['gross_acc_rank'])/4
df.sort_values('weighted_rank', ascending=True,inplace=True)

# %%
df.head(10)
# Out:
#                          model_name  \
# 7   CDBFP_1D_temporal_simulation_68
# 0   CDBFP_1D_temporal_simulation_93
# 5   CDBFP_1D_temporal_simulation_83
# 1   CDBFP_1D_temporal_simulation_53
# 6   CDBFP_1D_temporal_simulation_31
# 9   CDBFP_1D_temporal_simulation_64
# 10  CDBFP_1D_temporal_simulation_41
# 24  CDBFP_1D_temporal_simulation_30
# 12  CDBFP_1D_temporal_simulation_70
# 8   CDBFP_1D_temporal_simulation_61
#
#                                              features     tp_avg  \
# 7   ['price_5Ddiff', 'volume_sum15', 'SPY_20d_diff...  91.491018
# 0   ['price_5Ddiff', 'price_range_8MA_diff', 'roc_...  85.155689
# 5   ['price_change_H', 'volume_sum15_5DMA_diff', '...  86.658683
# 1   ['H-L', 'cd_vol3', 'SPY_20d_diff', 'cmf', 'rsi...  87.365269
# 6   ['return_vol_8H', 'price_change_H', 'macd', 'p...  87.916168
# 9   ['rsi', 'cmf', 'SPY_5d_diff', 'H-L', 'price_20...  85.185629
# 10  ['return_vol_8H', 'return_vol_5D', 'return_vol...  85.658683
# 24  ['price_3D20D_diff', 'H-PrevClose', 'High-Clos...  88.443114
# 12  ['roc3', 'price_10Ddiff', 'hour', 'volume_15MA...  89.155689
# 8   ['volume_sum15_10DMA_diff', 'DMplus', 'return_...  86.461078
#
#     gross_accuracy  num_features  median_tp  median_gross_accuracy  \
# 7         7.892216            45       74.0                    3.0
# 0        12.790419            25       74.0                    3.0
# 5         8.203593            48       70.0                    3.0
# 1         9.598802            48       69.0                    0.0
# 6         7.904192            28       69.0                   -1.0
# 9         7.233533            31       75.0                   -4.0
# 10        7.131737            25       71.0                   -4.0
# 24        3.772455            45       70.0                   -2.0
# 12        6.838323            35       72.0                   -7.0
# 8         7.353293            41       70.0                   -8.0
#
#     gross_acc_median_rank  median_tp_rank  tp_avg_rank  gross_acc_rank  \
# 7                       1               2            1               8
# 0                       2               4           21               1
# 5                       3              13            8               6
# 1                       4              23            6               2
# 6                      10              24            5               7
# 9                      21               1           20              10
# 10                     23               6           16              11
# 24                     13              17            4              25
# 12                     43               5            2              13
# 8                      56              10            9               9
#
#     weighted_rank
# 7            3.00
# 0            7.00
# 5            7.50
# 1            8.75
# 6           11.50
# 9           13.00
# 10          14.00
# 24          14.75
# 12          15.75
# 8           21.00

# %%
## Statistics of note
print(f"Best Strategies avg features {df.head(10)['num_features'].mean()}")
print(f"Best Strategies avg gross accuracy {df.head(10)['gross_accuracy'].mean()}")
print(f"Best Strategies avg median gross accuracy {df.head(10)['median_gross_accuracy'].mean()}")
print(f"Best Strategies avg median tp {df.head(10)['median_tp'].mean()}")
print(f"Best Strategies avg tp avg {df.head(10)['tp_avg'].mean()}")
# Out:
# Best Strategies avg features 37.1
# Best Strategies avg gross accuracy 7.871856287425149
# Best Strategies avg median gross accuracy -1.7
# Best Strategies avg median tp 71.4
# Best Strategies avg tp avg 87.3491017964072

# %%
df['features'] = df['features'].apply(lambda x: ast.literal_eval(x))
feature_df = df.explode('features')

# %%
feature_rank_avg = feature_df.groupby('features')['weighted_rank'].mean()
top_25_features_bfp1d = pd.DataFrame(feature_rank_avg).sort_values('weighted_rank', ascending=True).head(25).index.tolist()
top_25_features_bfp1d
# Out:
# ['price_change_H',
#  'DIminus',
#  'return_vol_10D',
#  'price_range',
#  'cd_vol3',
#  'DIplus',
#  'hour',
#  'return_vol_8H_diff',
#  'cmf_15MA',
#  'return_vol_8H',
#  'DX',
#  'return_vol_5D',
#  'cmf',
#  'rsi_15MA',
#  'day_of_week',
#  'High-Low',
#  'SPY_20d_diff',
#  'adx',
#  'cd_vol',
#  'bb_category',
#  'volume_sum15',
#  'volume_sum15_5DMA_diff',
#  'return_vol_10D_diff',
#  'DMplus',
#  'price_10Ddiff']

# %% [markdown]
# ### Selecting features for next round of tests

# %%
unique_values = list(set(top_25_features_bfp1d + top_25_features_bfc + top_25_features_bfc1d + top_25_features_bfp))
print(len(unique_values))
print(unique_values)
# Out:
# 53
# ['macd_15MA_diff', 'roc_15MA', 'price_3Ddiff', 'price_range', 'cd_vol', 'price_change_D', 'SPY_5d_diff', 'DX', 'H-PrevClose', 'price_change_H', 'High-Low', 'cmf_15MA', 'cmf', 'roc5', 'price_10Ddiff', 'TR', 'macd', 'roc_15MA_diff', 'roc', 'hour', 'return_vol_5D', 'volume_sum15_10DMA_diff', 'volume_sum15', 'return_vol_5D_diff', 'roc3', 'volume_sum15_5DMA_diff', 'bb_trend', 'bb_spread', 'DIminus', 'rsi_15MA', 'volume_15MA_diff', 'High-Close', 'price_range_5DMA_diff', 'Low-Close', 'return_vol_8H', 'SPY_20d_diff', 'price_range_8MA_diff', 'day_of_week', 'return_vol_10D', 'rsi', 'rsi_15MA_diff', 'H-L', 'macd_15MA', 'PrevClose-L', 'month', 'price_5Ddiff', 'return_vol_8H_diff', 'adx', 'cd_vol3', 'DIplus', 'return_vol_10D_diff', 'DMplus', 'bb_category']

# %%
# Out:
# 110
